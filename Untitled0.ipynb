# %% [markdown]
# <a href="https://colab.research.google.com/github/linssenste/application-website/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Spotify data analyiss
#
# This Notebook has the intention to do some basic analysis from my favorite artists from spotify for my application website

# %%
SPOTIFY_AUTH_URL     = 'https://accounts.spotify.com/api/token'
SPOTIFY_API_URL = 'https://api.spotify.com/v1'

SPOTIFY_PLAYLIST_ID = '0L58LDDYpBh7hncDnluUPl';

DRIVE_FOLDER = "/content/drive/My Drive/spotify-analysis"

# %%
import json
import requests
from requests.auth import HTTPBasicAuth
from collections import Counter
from collections import defaultdict
from collections import defaultdict
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
from google.colab import drive

import matplotlib.pyplot as plt

# %% [markdown]
# # Authentication

# %%
client_id = '6594e594a304499cbadcaaf40bc64370'
client_secret = '1cf6175b63204b0c8b4fe02d30b49988'

# Make a POST request to the Spotify Accounts service
response = requests.post(SPOTIFY_AUTH_URL, {
    'grant_type': 'client_credentials'
}, auth=HTTPBasicAuth(client_id, client_secret))

# Convert the response to JSON
data = response.json()

# Your new access token
access_token = data['access_token']

# Update your headers with the new access token
headers = {
    'Authorization': f'Bearer {access_token}'
}

# %% [markdown]
# # Fetch playlist data

# %%
drive.mount('/content/drive')
# Create a folder in the root directory
# !mkdir -p DRIVE_FOLDER
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def fetchPlaylistTracks(url, headers):
    formatted_data = []
    tracks = []

    while url:
        response = requests.get(url, headers=headers)
        data = response.json()

        for item in data['items']:
            track = item['track']
            album = track['album']

            tracks.append(track['id'])

            # Check if the album already exists in formatted_data
            existing_album = next((item for item in formatted_data if item['id'] == album['id']), None)

            if existing_album:
                # If the album exists, add the track to the album's tracks
                if track['id'] not in existing_album['tracks']:
                    existing_album['tracks'].append(track['id'])
            else:
                # If the album does not exist, create a new entry for the album
                formatted_album = {
                    'cover': album['images'][0]['url'].removeprefix('https://i.scdn.co/image/ab67616d0000b273'),
                    'id': album['id'],
                    'name': album['name'],
                    'artists': [{'name': artist['name'], 'id': artist['id']} for artist in album['artists']],
                    'release': album['release_date'],
                    'tracks': [track['id']]
                }

                # Add the constructed album/track data to your list
                formatted_data.append(formatted_album)

        url = data.get('next')  # URL for the next set of items, if any

    return formatted_data, tracks

# %%
albums, tracks = fetchPlaylistTracks(f'{SPOTIFY_API_URL}/playlists/{SPOTIFY_PLAYLIST_ID}/tracks', headers);


# stats
print("Albums: " + str(len(albums)));
print("Songs:" + str(len(tracks)))


# save file to google drive
with open(f'{DRIVE_FOLDER}/spotify-covers.json', 'w') as f:
  json.dump(albums, f)
# Out:
# Albums: 244
# Songs:858

# %%
import json
import base64
import requests

# Your GitHub Personal Access Token - Be careful with this!
GITHUB_TOKEN = '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'
REPO_OWNER = 'linssenste'
REPO_NAME = 'application-website'
FILE_PATH = 'src/assets/spotify-covers.json'
BRANCH = 'main'

# The content you want to push
albums = {'your': 'data'}

# Base64 encode the file content
content_encoded = base64.b64encode(json.dumps(albums).encode('utf-8')).decode('utf-8')

headers = {
    'Authorization': f'token {GITHUB_TOKEN}',
    'Accept': 'application/vnd.github.v3+json',
}

# Prepare the request payload
data = {
    'message': 'Commit message',
    'branch': BRANCH,
    'content': content_encoded,
}

# The GitHub API endpoint for creating or updating a file
url = f'https://api.github.com/repos/{REPO_OWNER}/{REPO_NAME}/contents/{FILE_PATH}'

response = requests.put(url, headers=headers, json=data)

if response.status_code == 201:
    print('File successfully committed.')
else:
    print('Error:', response.json())
# Out:
# Error: {'message': 'Invalid request.\n\n"sha" wasn\'t supplied.', 'documentation_url': 'https://docs.github.com/rest/repos/contents#create-or-update-file-contents'}

# %% [markdown]
# # Analyze data

# %% [markdown]
# ## Analyze artist occurences (TOP5)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-26d625aff4fb> in <cell line: 5>()
#       3
#       4 artist_percentages = {artist_id: (count / total_albums) * 100 for artist_id, count in artist_counts.items()}
# ----> 5 artist_ids = list(set([artist['id'] for album in albums for artist in album['artists']]))
#       6
#
# <ipython-input-39-26d625aff4fb> in <listcomp>(.0)
#       3
#       4 artist_percentages = {artist_id: (count / total_albums) * 100 for artist_id, count in artist_counts.items()}
# ----> 5 artist_ids = list(set([artist['id'] for album in albums for artist in album['artists']]))
#       6
#
# TypeError: string indices must be integers

# %%
# Step 1: Count the occurrence of each artist name
artist_names = [artist['id'] for album in albums for artist in album['artists']]
artist_counts = Counter(artist_names)

# Step 2: Create a mapping of artist names to their IDs. Note: This might overwrite some IDs if names are not unique.
nameMap = {artist['id']: artist['name'] for album in albums for artist in album['artists']}

# Calculate total number of albums
totalAlbums = len(albums)

# Step 3: Calculate the percentage of albums for each artist ID
artist_percentages = {artistId: (count / totalAlbums) * 100 for artistId, count in artist_counts.items()}

# Print the results (optional)
print("Artist Percentages:", artist_percentages)
print("Name to ID Mapping:", nameMap)
# Out:
# Artist Percentages: {'0MZ55DwuMQ1B2TXq9lcrE4': 1.639344262295082, '5fNCrHCBzuRdM8AbVajVh0': 2.8688524590163933, '2f7f3AmL16mmiAmYnxmmfx': 1.639344262295082, '1anyVhU62p31KFi8MEzkbf': 1.639344262295082, '3utZ2yeQk0Z3BCOBWP7Vlu': 1.639344262295082, '72udTJKu1pGovvS9aCYGMI': 1.639344262295082, '6hT4TLnkb8e4XI3BmJI66v': 0.819672131147541, '0s55qBss5MHYMKxhIqJsSA': 0.819672131147541, '383SVV0agxDRv1X2dKHsUb': 0.819672131147541, '4A8zidtceueyZzHKrE5wvs': 1.2295081967213115, '3OYM3jjPVR60kOqmamRRgk': 1.639344262295082, '2DysK49GjODUdRupTMZrfb': 0.819672131147541, '2XbRunIT35jrB8HRsISPgT': 2.459016393442623, '0k70gnDBLPirCltbTzoxuM': 2.0491803278688523, '2wY79sveU1sp5g7SokKOiI': 0.4098360655737705, '4riceIF5JCEKaSIwwLqIYt': 2.459016393442623, '4dfYua3wPCN3mq8EStDZkZ': 0.4098360655737705, '23xqmJEN3oVxwzqtNIyR5m': 2.459016393442623, '5wD0owYApRtYmjPWavWKvb': 0.819672131147541, '3FFqyoSbYAiE91jM3DAUb1': 1.2295081967213115, '6rqlONGmPuP2wJVSfliLBI': 0.819672131147541, '5WUlDfRSoLAfcVSX1WnrxN': 
# ...

# %%
sorted_artist_percentages = sorted(artist_percentages.items(), key=lambda x: x[1], reverse=True)

# TOP 5
print(dict(sorted_artist_percentages[:10]))
# Out:
# {'5fNCrHCBzuRdM8AbVajVh0': 2.8688524590163933, '2XbRunIT35jrB8HRsISPgT': 2.459016393442623, '4riceIF5JCEKaSIwwLqIYt': 2.459016393442623, '23xqmJEN3oVxwzqtNIyR5m': 2.459016393442623, '2jmpnuwn52LqrQASBlyQGJ': 2.459016393442623, '73sIBHcqh3Z3NyqHKZ7FOL': 2.459016393442623, '7BSNHln0lSqyDHdQ3sv0Q5': 2.459016393442623, '6jL3G5P8rxfUamkyqmRJNU': 2.459016393442623, '3nDNDLcZuSto4k9u4AbcLB': 2.459016393442623, '7dGJo4pcD2V6oG8kP0tJRR': 2.459016393442623}

# %% [markdown]
# ## Get & map artist genres

# %%
sorted_artist_percentages = sorted(artist_percentages.items(), key=lambda x: x[1], reverse=True)

# TOP 5
print(dict(sorted_artist_percentages[:5]))
fav_artists = dict(sorted_artist_percentages[:5])
print('5fNCrHCBzuRdM8bVajVh0' in fav_artists)
print(fav_artists['5fNCrHCBzuRdM8AbVajVh0'])
# Out:
# {'5fNCrHCBzuRdM8AbVajVh0': 2.8688524590163933, '2XbRunIT35jrB8HRsISPgT': 2.459016393442623, '4riceIF5JCEKaSIwwLqIYt': 2.459016393442623, '23xqmJEN3oVxwzqtNIyR5m': 2.459016393442623, '2jmpnuwn52LqrQASBlyQGJ': 2.459016393442623}
# False
# 2.8688524590163933

# %%
import requests
from collections import Counter

# Assuming artist_percentages, artist_ids, fav_artists, SPOTIFY_API_URL, and headers are defined elsewhere

sorted_artist_percentages = sorted(artist_percentages.items(), key=lambda x: x[1], reverse=True)
print(dict(sorted_artist_percentages[:5]))  # Display top 5 artists

genre_counts = Counter()

# Function to fetch artist data
def fetch_artist_data(artist_id):
    response = requests.get(f'{SPOTIFY_API_URL}/artists/{artist_id}', headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        return None

fav_artists_stats = {}

# Function to process albums and update stats for favorite artists
def process_albums(albums, fav_artists, fav_artists_stats):
    for album in albums:
        album_artist_ids = [artist['id'] for artist in album['artists']]
        for artist_id in album_artist_ids:
            if artist_id in fav_artists:
                if artist_id not in fav_artists_stats:
                    fav_artists_stats[artist_id] = {
                         'img': '',
                        'tracks': len(album['tracks']),
                        'albums': 1,
                        'occurrence': fav_artists[artist_id],
                        'name':''
                    }
                else:
                    fav_artists_stats[artist_id]['tracks'] += len(album['tracks'])
                    fav_artists_stats[artist_id]['albums'] += 1

# Process albums data structure here
process_albums(albums, fav_artists, fav_artists_stats)

# Iterate through each unique artist and collect their genres
for artist_id in set(artist_ids):
    artist_data = fetch_artist_data(artist_id)

    if artist_data:
      genres = artist_data.get('genres', []);
      genre_counts.update(genres);

      if (artist_id in fav_artists_stats):
        print(artist_data)
        fav_artists_stats[artist_id]['name'] = artist_data.get("name", '')
        fav_artists_stats[artist_id]['img'] =  (artist_data['images'][0]['url'])



print(dict(genre_counts))  # Convert Counter to regular dict for readability
print(fav_artists_stats)  # Display favorite artists stats
# Out:
# {'5fNCrHCBzuRdM8AbVajVh0': 2.8688524590163933, '2XbRunIT35jrB8HRsISPgT': 2.459016393442623, '4riceIF5JCEKaSIwwLqIYt': 2.459016393442623, '23xqmJEN3oVxwzqtNIyR5m': 2.459016393442623, '2jmpnuwn52LqrQASBlyQGJ': 2.459016393442623}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/2XbRunIT35jrB8HRsISPgT'}, 'followers': {'href': None, 'total': 16869}, 'genres': ['german indie', 'german pop'], 'href': 'https://api.spotify.com/v1/artists/2XbRunIT35jrB8HRsISPgT', 'id': '2XbRunIT35jrB8HRsISPgT', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb65e8d02a37ce4b2371caf085', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab6761610000517465e8d02a37ce4b2371caf085', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f17865e8d02a37ce4b2371caf085', 'width': 160}], 'name': 'Tristan Brusch', 'popularity': 36, 'type': 'artist', 'uri': 'spotify:artist:2XbRunIT35jrB8HRsISPgT'}
# ...

# %%
# Assuming genre_counts is a dictionary containing your genre data
sorted_genres = sorted(genre_counts.items(), key=lambda x: x[1], reverse=True)

# Print the top 8 genres as a dictionary
print(dict(sorted_genres[:8]))

# Unzip the sorted genres and their counts into two separate lists
genres, counts = zip(*sorted_genres[:8])

# Print the two arrays
print(list(genres))  # Array of genre strings
print(list(counts))  # Array of corresponding values
# Out:
# {'german pop': 21, 'german hip hop': 15, 'german indie': 15, 'pop': 12, 'german alternative rap': 12, 'antideutsche': 7, 'german cloud rap': 5, 'swiss indie': 5}
# ['german pop', 'german hip hop', 'german indie', 'pop', 'german alternative rap', 'antideutsche', 'german cloud rap', 'swiss indie']
# [21, 15, 15, 12, 12, 7, 5, 5]

# %%
# Out:
# [('german pop', 21), ('german indie', 15), ('german hip hop', 15), ('german alternative rap', 12), ('pop', 12), ('antideutsche', 7), ('german cloud rap', 5), ('swiss indie', 5), ('german singer-songwriter', 4), ('german jazz rap', 4), ('uk pop', 4), ('german reggae', 4), ('rap', 4), ('hamburg hip hop', 4), ('rock', 3), ('german rock', 3), ('volkspop', 3), ('hip hop', 3), ('bayerischer rap', 3), ('art pop', 3), ('classic rock', 2), ('glam rock', 2), ('edm', 2), ('german indie rock', 2), ('chicago rap', 2), ('hamburg indie', 2), ('german indie folk', 2), ('jamaican dancehall', 1), ('dance pop', 1), ('electro house', 1), ('moombahton', 1), ('pop dance', 1), ('electronic rock', 1), ('german alternative rock', 1), ('deep german hip hop', 1), ('conscious hip hop', 1), ('pop rap', 1), ('trap', 1), ('german boom bap', 1), ('folk-pop', 1), ('irish pop', 1), ('modern rock', 1), ('swiss rock', 1), ('cologne indie', 1), ('blasmusik', 1), ('ambient', 1), ('art rock', 1), ('compositional ambient',
# ...

# %%
import re
from collections import Counter

# Updated list of general genres
general_genres = ['pop', 'indie', 'hip hop', 'rap', 'rock', 'edm', 'jazz', 'reggae', 'singer-songwriter', 'ambient', 'experimental', 'house', 'dance', 'electro', 'folk', 'alternative', 'punk', 'ska', 'metal', 'classical', 'country']

# Initialize a Counter for the general genres
general_genre_counts = Counter()

# Broaden matching rules and handle special cases
def match_general_genre(specific_genre, general_genres):
    # Special case handling
    if 'electro' in specific_genre or 'dance' in specific_genre:
        return 'electronic/dance'
    if 'hip hop' in specific_genre or 'rap' in specific_genre:
        return 'hip hop/rap'

    # Broadened matching rules
    for general_genre in general_genres:
        if general_genre in specific_genre:
            return general_genre
    return 'other'

# Categorize each specific genre
for specific_genre, count in genre_counts.items():
    general_genre = match_general_genre(specific_genre, general_genres)
    general_genre_counts[general_genre] += count


print(dict(general_genre_counts))
# Out:
# {'pop': 55, 'hip hop/rap': 59, 'electronic/dance': 7, 'other': 16, 'indie': 29, 'rock': 15, 'singer-songwriter': 5, 'ambient': 3, 'experimental': 1, 'edm': 2, 'reggae': 4, 'punk': 1, 'ska': 1, 'house': 2}

# %%
sorted_general_genres = sorted(general_genre_counts.items(), key=lambda x: x[1], reverse=True)

# Print the top 8 genres as a dictionary


# Unzip the sorted genres and their counts into two separate lists
genres, counts = zip(*sorted_general_genres[:8])

# Print the two arrays
print(list(genres))  # Array of genre strings
print(list(counts))  # Array of corresponding values
# Out:
# ['hip hop/rap', 'pop', 'indie', 'other', 'rock', 'electronic/dance', 'singer-songwriter', 'reggae']
# [59, 55, 29, 16, 15, 7, 5, 4]

# %%
# Prepare data for the radar chart
genres = list(genre_counts.keys())
counts = list(genre_counts.values())
counts += counts[:1]  # Completing the loop

# Calculate angle for each genre
num_vars = len(genres)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]

# Plot
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.fill(angles, counts, color='green', alpha=0.25)
ax.plot(angles, counts, color='green', linewidth=2)

# Replace the labels
ax.set_xticks(angles[:-1])
ax.set_xticklabels(genres, size=8)

plt.title('Genre Distribution in My Music Collection')
plt.show()

# %% [markdown]
# ## Audio features

# %%
# Deduplicate the track IDs in case the same track appears more than once
unique_track_ids = set(tracks)

# Dictionary to hold audio features for each track, along with popularity
audio_features_data = {}

# Spotify limits the number of track IDs you can request at once to 100
batch_size = 100
for i in range(0, len(unique_track_ids), batch_size):
    batch = list(unique_track_ids)[i:i+batch_size]
    response = requests.get((f'{SPOTIFY_API_URL}/audio-features/'), headers=headers, params={'ids': ','.join(batch)})
    data = response.json()

    # For each track, fetch its audio features
    for feature in data['audio_features']:
        if feature:  # Check if the feature is not None
            track_id = feature['id']

            # Remove 'track_href' and 'analysis_url' from the feature data
            feature.pop('track_href', None)  # Use pop to remove 'track_href', if it exists
            feature.pop('analysis_url', None)  # Use pop to remove 'analysis_url', if it exists
            feature.pop('uri', None)  # Use pop to remove 'analysis_url', if it exists

            audio_features_data[track_id] = feature

# Now, 'audio_features_data' contains both the audio features and popularity for each track
print(audio_features_data)

# Initialize a dictionary to hold the sum of each feature
features_sum = {key: 0 for key in audio_features_data[list(audio_features_data.keys())[0]].keys() if key != 'type' and key != 'id' and key != 'uri' and key != 'track_href' and key != 'analysis_url' and key != 'duration_ms' and key != 'time_signature'}

# Sum up all the features
for features in audio_features_data.values():
    for key, value in features.items():
        if key in features_sum:
            features_sum[key] += value

# Calculate the average
features_avg = {key: (value / len(audio_features_data)) for key, value in features_sum.items()}

# speechiness: 14% --> more music less text
# 'valence': 46.94867990654203 % --> tracks with low valence sound more negative (e.g. sad, depressed, angry)
# 'danceability': 62.282593457943904, 'energy': 60.837155373831706
print(features_avg)

with open('/content/drive/My Drive/spotify/features.json', 'w') as f:
  json.dump(data, f)
# Out:
# {'5hqxBvQJ3XJDSbxT9vyyqA': {'danceability': 0.811, 'energy': 0.816, 'key': 8, 'loudness': -4.887, 'mode': 1, 'speechiness': 0.129, 'acousticness': 0.186, 'instrumentalness': 0, 'liveness': 0.629, 'valence': 0.313, 'tempo': 133.876, 'type': 'audio_features', 'id': '5hqxBvQJ3XJDSbxT9vyyqA', 'duration_ms': 260093, 'time_signature': 4}, '1hUT7kFty1Sgfngm51vHPO': {'danceability': 0.722, 'energy': 0.471, 'key': 11, 'loudness': -13.064, 'mode': 0, 'speechiness': 0.451, 'acousticness': 0.16, 'instrumentalness': 0, 'liveness': 0.231, 'valence': 0.384, 'tempo': 120.028, 'type': 'audio_features', 'id': '1hUT7kFty1Sgfngm51vHPO', 'duration_ms': 135133, 'time_signature': 3}, '3YQYiLfVOlYk66wxI0N9W9': {'danceability': 0.829, 'energy': 0.492, 'key': 0, 'loudness': -9.471, 'mode': 0, 'speechiness': 0.477, 'acousticness': 0.317, 'instrumentalness': 0, 'liveness': 0.209, 'valence': 0.885, 'tempo': 92.923, 'type': 'audio_features', 'id': '3YQYiLfVOlYk66wxI0N9W9', 'duration_ms': 147840, 'time_signature':
# ...

# %%
from collections import defaultdict
import pandas as pd

# Initialize a defaultdict to count albums per decade
decade_counts = defaultdict(int)

for details in albums:
    # Extract year from the release_date
    date = pd.to_datetime(details['release'])

    # Convert year to its corresponding decade
    year = date.year
    decade = (year // 10) * 10

    # Count albums per decade
    decade_counts[decade] += len(details['tracks'])

sorted_counts = sorted(decade_counts.items())

print(dict(sorted_counts))
# Out:
# {1960: 2, 1970: 8, 1990: 6, 2000: 12, 2010: 422, 2020: 406}

# %%
from collections import defaultdict
import pandas as pd
import numpy as np
import matplotlib.dates as mdates

dateGranularity = '%Y'  # Use '%Y-%m' if you want year-month granularity
# Initialize a defaultdict to count albums per year
yearly_counts = defaultdict(int)

for details in albums:
    # Extract year from the release_date
    date = pd.to_datetime(details['release'])

    filterMethod = date.strftime(dateGranularity)
    yearly_counts[filterMethod] += 1

sorted_counts = sorted(yearly_counts.items())

print(sorted_counts)
# Unpack the sorted list into separate lists for plotting
dates, counts = zip(*sorted_counts)

# Convert string dates to datetime objects for plotting
dates = pd.to_datetime(dates)

plt.figure(figsize=(12, 6))

# Plotting
plt.plot(dates, counts, marker='o', linestyle='-')

plt.title('Favorite Album Releases Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Albums')

# Formatting the date axis for better readability
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter(dateGranularity))
plt.gca().xaxis.set_major_locator(mdates.YearLocator(base=5))  # Show every 5 years

plt.xticks(rotation=45)

plt.grid(True)
plt.show()
# Out:
# [('1969', 1), ('1975', 1), ('1977', 1), ('1978', 1), ('1992', 1), ('2002', 1), ('2007', 1), ('2008', 1), ('2010', 1), ('2011', 2), ('2012', 9), ('2013', 8), ('2014', 7), ('2015', 12), ('2016', 17), ('2017', 17), ('2018', 17), ('2019', 24), ('2020', 17), ('2021', 21), ('2022', 23), ('2023', 45), ('2024', 16)]

# %%
# Converting the top 10 sorted_artist_percentages into a dictionary
top_artists = dict(sorted_artist_percentages[:10])

# Constructing the data structure
dataResult = {
    "stats": {
        "albums": len(albums),
        "tracks": len(tracks),
        "artists": len(artist_percentages)
    },
    "features": dict(features_avg),
    "genres": dict(general_genre_counts),
    "artists": fav_artists_stats,
    "decades": dict(sorted_counts)

}

# Serializing the dataResult dictionary to a JSON-formatted string
dataResult_json = json.dumps(dataResult, indent=4)

# Printing out the resulting JSON
print(dataResult_json)
# Out:
# {
#     "stats": {
#         "albums": 244,
#         "tracks": 858,
#         "artists": 105
#     },
#     "features": {
#         "danceability": 0.6228259345794396,
#         "energy": 0.6083715537383174,
#         "key": 5.292056074766355,
#         "loudness": -7.748959112149523,
#         "mode": 0.5642523364485982,
#         "speechiness": 0.1483230140186916,
#         "acousticness": 0.3113155894859814,
#         "instrumentalness": 0.03693986550233646,
#         "liveness": 0.2103723130841124,
#         "valence": 0.4694867990654206,
#         "tempo": 119.33049649532714
#     },
#     "genres": {
#         "pop": 55,
#         "hip hop/rap": 59,
#         "electronic/dance": 7,
#         "other": 16,
#         "indie": 29,
#         "rock": 15,
#         "singer-songwriter": 5,
#         "ambient": 3,
#         "experimental": 1,
#         "edm": 2,
#         "reggae": 4,
#         "punk": 1,
#         "ska": 1,
#         "house": 2
#     },
#     "artists": {
# ...

# %%
print(information);
openPythonNotebook();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-fd68d88ff46a> in <cell line: 1>()
# ----> 1 print(information);
#       2 openPythonNotebook();
#
# NameError: name 'information' is not defined

# %%
test
